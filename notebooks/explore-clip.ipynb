# %% [markdown]
# # Explore CLIP
#
# ## Purpose of this notebook
#
# > Assess how CLIP understands local attributes for the furniture domain.
#
# The goal is to assess how well CLIP is able to identifies specific details from the images from our domain, i.e. how well it can differentiate details for furniture.
#
# <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@4.0.0/dist/css/bootstrap.min.css" integrity="sha384-Gn5384xqQ1aoWXA+058RXPxPg6fy4IWvTNh0E263XmFcJlSAwiGgFAW/dAiS6JXm" crossorigin="anonymous">
#
# <div class="alert alert-primary" role="alert">
#
#   <h4 class="alert-heading">Example</h4>
#
# Is "a metallic chair" the same as "a chair with metallic legs"? How about "a char with metallic back"?
# </div>
#
# It is crucial to have a fine tunned CLIP model, since it affects the whole generation process.

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# loads libs
import os
import pandas as pd
from PIL import Image
from IPython.core.display import HTML

from src.helpers import path_to_image_html
from src.models.clip import get_clip_df

# %%
# set input parameters
text_prompts = [
    'a chair',
    'a wooden chair',
    'a chair with wooden legs',
    'a chair with wooden back',
    'a chair with wooden seat',
    'a table',
    'a dog'
    ]

img_urls = ['https://www.iconmobel.de/2897-large_default/stuhl-tolix-wood-style.jpg',
             'https://3dwarehouse.sketchup.com/warehouse/v1.0/content/public/3c602043-655e-4259-b656-47e70224fa29',
             'https://media.designconnected.com/vfs/1f8f73b360dc9221777f7b1dcec8c357_1/756923d1ce62e45147d79e7d6df25f5a.jpg',
             'https://image.made-in-china.com/2f0j00bmuEdokzffcn/Emes-Chair-Replica-Design-Dining-Chair-Plastic-Chair-with-Wooden-Legs.jpg'
             ]

# infers similarities
df = get_clip_df(img_urls, text_prompts)

# presents data
df.style.background_gradient(axis=1).format_index(path_to_image_html)
# Out:
# 100%|██████████| 4/4 [00:11<00:00,  2.79s/it]
# <style type="text/css">
# #T_1ae40_row0_col0 {
#   background-color: #1e80b8;
#   color: #f1f1f1;
# }
# #T_1ae40_row0_col1 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_1ae40_row0_col2 {
#   background-color: #197db7;
#   color: #f1f1f1;
# }
# #T_1ae40_row0_col3 {
#   background-color: #046299;
#   color: #f1f1f1;
# }
# #T_1ae40_row0_col4, #T_1ae40_row1_col4, #T_1ae40_row2_col0, #T_1ae40_row3_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_1ae40_row0_col5 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_1ae40_row0_col6, #T_1ae40_row1_col6, #T_1ae40_row2_col6, #T_1ae40_row3_col6 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_1ae40_row1_col0 {
#   background-color: #157ab5;
#   color: #f1f1f1;
# }
# #T_1ae40_row1_col1 {
#   background-color: #056fae;
#   color: #f1f1f1;
# }
# #T_1ae40_row1_col2 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_1ae40_row1_col3 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_1ae40_row1_col5 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_1ae40_row2_col1 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_1ae40_row2_col2 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
# }
# #T_1ae40_row2_col3 {
#   background-color: #2182b9;
#   color: #f1f1f1;
# }
# #T_1ae40_row2_col4 {
#   background-color: #529bc7;
#   color: #f1f1f1;
# }
# #T_1ae40_row2_col5 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_1ae40_row3_col0 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_1ae40_row3_col1 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_1ae40_row3_col3 {
#   background-color: #569dc8;
#   color: #f1f1f1;
# }
# #T_1ae40_row3_col4 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_1ae40_row3_col5 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# </style>
# <table id="T_1ae40">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1ae40_level0_col0" class="col_heading level0 col0" >a chair</th>
#       <th id="T_1ae40_level0_col1" class="col_heading level0 col1" >a wooden chair</th>
#       <th id="T_1ae40_level0_col2" class="col_heading level0 col2" >a chair with wooden legs</th>
#       <th id="T_1ae40_level0_col3" class="col_heading level0 col3" >a chair with wooden back</th>
#       <th id="T_1ae40_level0_col4" class="col_heading level0 col4" >a chair with wooden seat</th>
#       <th id="T_1ae40_level0_col5" class="col_heading level0 col5" >a table</th>
#       <th id="T_1ae40_level0_col6" class="col_heading level0 col6" >a dog</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1ae40_level0_row0" class="row_heading level0 row0" ><img src="https://www.iconmobel.de/2897-large_default/stuhl-tolix-wood-style.jpg" height="150" ></th>
#       <td id="T_1ae40_row0_col0" class="data row0 col0" >0.198730</td>
#       <td id="T_1ae40_row0_col1" class="data row0 col1" >0.064514</td>
#       <td id="T_1ae40_row0_col2" class="data row0 col2" >0.201904</td>
#       <td id="T_1ae40_row0_col3" class="data row0 col3" >0.239746</td>
#       <td id="T_1ae40_row0_col4" class="data row0 col4" >0.289307</td>
#       <td id="T_1ae40_row0_col5" class="data row0 col5" >0.005730</td>
#       <td id="T_1ae40_row0_col6" class="data row0 col6" >0.000011</td>
#     </tr>
#     <tr>
#       <th id="T_1ae40_level0_row1" class="row_heading level0 row1" ><img src="https://3dwarehouse.sketchup.com/warehouse/v1.0/content/public/3c602043-655e-4259-b656-47e70224fa29" height="150" ></th>
#       <td id="T_1ae40_row1_col0" class="data row1 col0" >0.185547</td>
#       <td id="T_1ae40_row1_col1" class="data row1 col1" >0.197510</td>
#       <td id="T_1ae40_row1_col2" class="data row1 col2" >0.188477</td>
#       <td id="T_1ae40_row1_col3" class="data row1 col3" >0.158691</td>
#       <td id="T_1ae40_row1_col4" class="data row1 col4" >0.261719</td>
#       <td id="T_1ae40_row1_col5" class="data row1 col5" >0.008026</td>
#       <td id="T_1ae40_row1_col6" class="data row1 col6" >0.000010</td>
#     </tr>
#     <tr>
#       <th id="T_1ae40_level0_row2" class="row_heading level0 row2" ><img src="https://media.designconnected.com/vfs/1f8f73b360dc9221777f7b1dcec8c357_1/756923d1ce62e45147d79e7d6df25f5a.jpg" height="150" ></th>
#       <td id="T_1ae40_row2_col0" class="data row2 col0" >0.328125</td>
#       <td id="T_1ae40_row2_col1" class="data row2 col1" >0.075562</td>
#       <td id="T_1ae40_row2_col2" class="data row2 col2" >0.181274</td>
#       <td id="T_1ae40_row2_col3" class="data row2 col3" >0.222046</td>
#       <td id="T_1ae40_row2_col4" class="data row2 col4" >0.187012</td>
#       <td id="T_1ae40_row2_col5" class="data row2 col5" >0.006012</td>
#       <td id="T_1ae40_row2_col6" class="data row2 col6" >0.000021</td>
#     </tr>
#     <tr>
#       <th id="T_1ae40_level0_row3" class="row_heading level0 row3" ><img src="https://image.made-in-china.com/2f0j00bmuEdokzffcn/Emes-Chair-Replica-Design-Dining-Chair-Plastic-Chair-with-Wooden-Legs.jpg" height="150" ></th>
#       <td id="T_1ae40_row3_col0" class="data row3 col0" >0.073608</td>
#       <td id="T_1ae40_row3_col1" class="data row3 col1" >0.053040</td>
#       <td id="T_1ae40_row3_col2" class="data row3 col2" >0.437012</td>
#       <td id="T_1ae40_row3_col3" class="data row3 col3" >0.245239</td>
#       <td id="T_1ae40_row3_col4" class="data row3 col4" >0.187988</td>
#       <td id="T_1ae40_row3_col5" class="data row3 col5" >0.003086</td>
#       <td id="T_1ae40_row3_col6" class="data row3 col6" >0.000004</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Conclusion
#
# CLIP seems to identify local details in some cases.
